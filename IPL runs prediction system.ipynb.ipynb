# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# !pip install --upgrade scikit-learn

# %%
data = pd.read_csv('/content/Ramasethu3003.csv')

# %%
data.head()
# Out:
#    Match Date  Venue  BatsmanTeam  BowlersTeam  Batsman  Bowler  \
# 0  15-04-2023      1            1            4       77      69
# 1  15-04-2023      1            1            4       12       8
# 2  15-04-2023      1            1            4       19      90
# 3  15-04-2023      1            1            4       27      54
# 4  15-04-2023      1            1            4       16      19
#
#    RunsPreviousPerformance  BatsmanOverallPerformance  StrikeRate  \
# 0                       84                          3         168
# 1                       68                          2         243
# 2                       49                          3         163
# 3                       73                          2         183
# 4                       59                          2         184
#
#    AvgRunsPerInning  ...  BowlerRecentWickets  BowlerOverallPerformance  \
# 0                84  ...                    3                         1
# ...

# %%
data.columns.unique()
# Out:
# Index(['Venue', 'BatsmanTeam', 'BowlersTeam', 'Batsman', 'Bowler',
#        'RunsPreviousPerformance', 'BatsmanOverallPerformance', 'StrikeRate',
#        'AvgRunsPerInning', 'BatsmanBattingOrder', 'BatsmanAge',
#        'BatsmanExperience', 'BatsmanFitness', 'BatsmanPreferredShots',
#        'BatsmanStrengths', 'BatsmanAbilityPace', 'BatsmanAbilitySpin',
#        'BowlerRecentWickets', 'BowlerOverallPerformance',
#        'BowlerLastseasonWickets', 'BowlerAccuracy', 'BowlersWorkload',
#        'MatchWeatherConditions', 'BowlerFitness', 'FieldingPositions',
#        'EconomyRate', 'PredictedRunsPerOver'],
#       dtype='object')

# %%
data.tail()
# Out:
#      Match Date  Venue  BatsmanTeam  BowlersTeam  Batsman  Bowler  \
# 963  19-07-2023      5            4            1       31      54
# 964  19-07-2023      5            4            1       48       8
# 965  19-07-2023      5            4            1        8      22
# 966  19-07-2023      5            4            1        7      54
# 967  21-07-2023      6            5            3       31       5
#
#      RunsPreviousPerformance  BatsmanOverallPerformance  StrikeRate  \
# 963                       74                          3         176
# 964                       56                          1         170
# 965                       42                          1         140
# 966                       36                          1         164
# 967                       92                          1         167
#
#      AvgRunsPerInning  ...  BowlerRecentWickets  BowlerOverallPerformance  \
# 963                74  ...                    0                         2
# ...

# %%
data.dtypes
# Out:
# Match Date                   object
# Venue                         int64
# BatsmanTeam                   int64
# BowlersTeam                   int64
# Batsman                       int64
# Bowler                        int64
# RunsPreviousPerformance       int64
# BatsmanOverallPerformance     int64
# StrikeRate                    int64
# AvgRunsPerInning              int64
# BatsmanBattingOrder           int64
# BatsmanAge                    int64
# BatsmanExperience             int64
# BatsmanFitness                int64
# BatsmanPreferredShots         int64
# BatsmanStrengths              int64
# BatsmanAbilityPace            int64
# BatsmanAbilitySpin            int64
# BowlerRecentWickets           int64
# BowlerOverallPerformance      int64
# BowlerLastseasonWickets       int64
# BowlerAccuracy                int64
# BowlersWorkload               int64
# MatchWeatherConditions        int64
# BowlerFitness                 int64
# FieldingPositions             int64
# ...

# %%
data.shape
# Out:
# (968, 28)

# %%
data.describe()
# Out:
#             Venue  BatsmanTeam  BowlersTeam     Batsman      Bowler  \
# count  968.000000   968.000000   968.000000  968.000000  968.000000
# mean     3.663223     3.138430     2.989669   36.015496   40.902893
# std      1.597636     1.128484     1.417827   23.532696   30.161387
# min      1.000000     1.000000     1.000000    1.000000    2.000000
# 25%      2.000000     2.000000     2.000000   22.000000   18.000000
# 50%      4.000000     3.000000     3.000000   32.000000   30.000000
# 75%      5.000000     4.000000     4.000000   45.000000   69.000000
# max      7.000000     5.000000     5.000000  189.000000  101.000000
#
#        RunsPreviousPerformance  BatsmanOverallPerformance  StrikeRate  \
# count               968.000000                 968.000000  968.000000
# mean                 64.044421                   1.954545  175.010331
# std                  18.043298                   0.809714   15.017463
# min                  30.000000                   1.000000  136.000000
# ...

# %%
data.isnull().sum()
# Out:
# Match Date                   0
# Venue                        0
# BatsmanTeam                  0
# BowlersTeam                  0
# Batsman                      0
# Bowler                       0
# RunsPreviousPerformance      0
# BatsmanOverallPerformance    0
# StrikeRate                   0
# AvgRunsPerInning             0
# BatsmanBattingOrder          0
# BatsmanAge                   0
# BatsmanExperience            0
# BatsmanFitness               0
# BatsmanPreferredShots        0
# BatsmanStrengths             0
# BatsmanAbilityPace           0
# BatsmanAbilitySpin           0
# BowlerRecentWickets          0
# BowlerOverallPerformance     0
# BowlerLastseasonWickets      0
# BowlerAccuracy               0
# BowlersWorkload              0
# MatchWeatherConditions       0
# BowlerFitness                0
# FieldingPositions            0
# EconomyRate                  0
# PredictedRunsPerOver         0
# dtype: int64

# %%
# visualizing correlation between columns
import matplotlib.pyplot as plt
import seaborn as sns

# Get correlation of all the features of the dataset
corr_matrix = data.corr()
top_corr_features = corr_matrix.index

# Plotting the heatmap
plt.figure(figsize=(40,25))
g = sns.heatmap(data=data[top_corr_features].corr(), annot=True, cmap='RdYlGn')
# Out:
# <ipython-input-27-546afa0d4791>:6: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix = data.corr()

# %%
col_remove = ['Match Date']
print('Before removing unwanted columns: {}'.format(data.shape))
data.drop(labels=col_remove, axis=1, inplace=True)
print('After removing unwanted columns: {}'.format(data.shape))
# Out:
# Before removing unwanted columns: (968, 28)
# After removing unwanted columns: (968, 27)

# %%
x = data.iloc[:,:-1]
y = data.iloc[:,-1]
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2)
print("Training set: {} and Test set: {}".format(X_train.shape, X_test.shape))
# Out:
# Training set: (774, 26) and Test set: (194, 26)

# %%
x
# Out:
#      Venue  BatsmanTeam  BowlersTeam  Batsman  Bowler  \
# 0        1            1            4       77      69
# 1        1            1            4       12       8
# 2        1            1            4       19      90
# 3        1            1            4       27      54
# 4        1            1            4       16      19
# ..     ...          ...          ...      ...     ...
# 963      5            4            1       31      54
# 964      5            4            1       48       8
# 965      5            4            1        8      22
# 966      5            4            1        7      54
# 967      6            5            3       31       5
#
#      RunsPreviousPerformance  BatsmanOverallPerformance  StrikeRate  \
# 0                         84                          3         168
# 1                         68                          2         243
# 2                         49                          3         163
# ...

# %%
y
# Out:
# 0      7
# 1      9
# 2      6
# 3      7
# 4      6
#       ..
# 963    7
# 964    7
# 965    7
# 966    5
# 967    9
# Name: PredictedRunsPerOver, Length: 968, dtype: int64

# %%
from sklearn.linear_model import LogisticRegression
logistic_regressor = LogisticRegression(solver='liblinear')
logistic_regressor.fit(X_train, y_train)
# Out:
# LogisticRegression(solver='liblinear')

# %%
y_pred_lgr = logistic_regressor.predict(X_test)

# %%
from sklearn.ensemble import RandomForestRegressor
random_regressor = RandomForestRegressor()
random_regressor.fit(X_train, y_train)
# Out:
# RandomForestRegressor()

# %%
y_pred_rf = random_regressor.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error as mae, mean_squared_error as mse
from sklearn.metrics import r2_score
print("---- Logistic Regression - Model Evaluation ----")
print("Mean Absolute Error (MAE): {}".format(mae(y_test, y_pred_rf)))
print("Mean Squared Error (MSE): {}".format(mse(y_test, y_pred_rf)))
print("Root Mean Squared Error (RMSE): {}".format(np.sqrt(mse(y_test, y_pred_rf))))
print("R2 Score : %.2f" %r2_score(y_test,y_pred_rf))
# Out:
# ---- Logistic Regression - Model Evaluation ----
# Mean Absolute Error (MAE): 1.6913402061855667
# Mean Squared Error (MSE): 4.466255670103093
# Root Mean Squared Error (RMSE): 2.1133517620365745
# R2 Score : -0.05

# %%
# Random Forest Regression - Model Evaluation
print("---- Random Forest Regression - Model Evaluation ----")
print("Mean Absolute Error (MAE): {}".format(mae(y_test, y_pred_rf)))
print("Mean Squared Error (MSE): {}".format(mse(y_test, y_pred_rf)))
print("Root Mean Squared Error (RMSE): {}".format(np.sqrt(mse(y_test, y_pred_rf))))
print("R2 score : %.2f" % r2_score(y_test,y_pred_rf))
# Out:
# ---- Random Forest Regression - Model Evaluation ----
# Mean Absolute Error (MAE): 1.6913402061855667
# Mean Squared Error (MSE): 4.466255670103093
# Root Mean Squared Error (RMSE): 2.1133517620365745
# R2 score : -0.05

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error

# Initialize Random Forest model
random_forest_model = RandomForestRegressor()

# Train the model
random_forest_model.fit(X_train, y_train)

# Make predictions on the test set
predictions = random_forest_model.predict(X_test)

# Evaluate the model
mse = mean_squared_error(y_test, predictions)
print("Mean Squared Error:", mse)
# Out:
# Mean Squared Error: 4.434919587628866

# %%
from sklearn.model_selection import GridSearchCV

# Define the parameter grid
param_grid = {
    'n_estimators': [100, 200, 300],
    'max_depth': [None, 10, 20],
    'min_samples_split': [2, 5, 10]
}

# Initialize Random Forest model
random_forest_model = RandomForestRegressor()

# Perform Grid Search CV
grid_search = GridSearchCV(random_forest_model, param_grid, cv=5, scoring='neg_mean_squared_error', n_jobs=-1)
grid_search.fit(X_train, y_train)

# Get the best parameters and model
best_params = grid_search.best_params_
best_model = grid_search.best_estimator_

# Make predictions on the test set using the best model
predictions = best_model.predict(X_test)

# Evaluate the model
mse = mean_squared_error(y_test, predictions)
print("Mean Squared Error (Test Accuracy):", mse)
print("Best Parameters:", best_params)
# Out:
# Mean Squared Error (Test Accuracy): 4.39930235303936
# Best Parameters: {'max_depth': None, 'min_samples_split': 10, 'n_estimators': 200}

# %%
new_data= pd.DataFrame({
    "Venue": [1],
    "BatsmanTeam": [1],
    "BowlersTeam": [4],
    "Batsman": [77],
    "Bowler": [69],
    "RunsPreviousPerformance": [84],
    "BatsmanOverallPerformance": [3],
    "StrikeRate": [168],
    "AvgRunsPerInning": [84],
    "BatsmanBattingOrder": [4],
    "BatsmanAge": [37],
    "BatsmanExperience": [14],
    "BatsmanFitness": [2],
    "BatsmanPreferredShots": [6],
    "BatsmanStrengths": [2],
    "BatsmanAbilityPace": [3],
    "BatsmanAbilitySpin": [3],
    "BowlerRecentWickets": [3],
    "BowlerOverallPerformance": [1],
    "BowlerLastseasonWickets": [29],
    "BowlerAccuracy": [1],
    "BowlersWorkload": [2],
    "MatchWeatherConditions": [3],
    "BowlerFitness": [2],
    "FieldingPositions": [2],
    "EconomyRate": [7],


})

# %%
new_data.head()
# Out:
#    Venue  BatsmanTeam  BowlersTeam  Batsman  Bowler  RunsPreviousPerformance  \
# 0      1            1            4       77      69                       84
#
#    BatsmanOverallPerformance  StrikeRate  AvgRunsPerInning  \
# 0                          3         168                84
#
#    BatsmanBattingOrder  ...  BatsmanAbilitySpin  BowlerRecentWickets  \
# 0                    4  ...                   3                    3
#
#    BowlerOverallPerformance  BowlerLastseasonWickets  BowlerAccuracy  \
# 0                         1                       29               1
#
#    BowlersWorkload  MatchWeatherConditions  BowlerFitness  FieldingPositions  \
# 0                2                       3              2                  2
#
#    EconomyRate
# 0            7
#
# [1 rows x 26 columns]

# %%
predictions = best_model.predict(new_data)

# %%
print(predictions)
# Out:
# [6.85194299]

# %%
input_data = (1,1,4,12,8,68,2,243,68,2,23,2,3,6,2,2,1,1,3,23,3,3,1,2,3,9)

# changing the input_data to numpy array
input_data_as_numpy_array = np.asarray(input_data)

# reshape the array as we are predicting for one instance
input_data_reshaped = input_data_as_numpy_array.reshape(1,-1)


prediction = best_model.predict(input_data_reshaped)
print(prediction)
# Out:
# [7.73335644]
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(

# %%
import pickle

# %%
filename = 'ipl_trained_model31.sav'
pickle.dump(best_model, open(filename, 'wb'))

# %%
# loading the saved model
loaded_model = pickle.load(open('ipl_trained_model31.sav', 'rb'))

# %%
input_data = (2,3,5,33,15,39,3,195,39,7,31,5,2,1,3,3,1,2,1,15,2,2,2,3,3,8)

# changing the input_data to numpy array
input_data_as_numpy_array = np.asarray(input_data)

# reshape the array as we are predicting for one instance
input_data_reshaped = input_data_as_numpy_array.reshape(1,-1)


prediction = loaded_model.predict(input_data_reshaped)
print(prediction)
# Out:
# [5.74723731]
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
